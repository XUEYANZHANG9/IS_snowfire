# %%
from pylab import *
# %matplotlib inline


subplot(211)
imshow(rand(100,100), cmap=cm.BuPu_r)
subplot(212)
imshow(rand(100,100), cmap=cm.BuPu_r)

# subplots_adjust(bottom=0.1, right=0.8, top=0.9)
subplots_adjust(bottom=0.2, right=0.9, top=1.0)
# cax = axes([0.85, 0.1, 0.075, 0.8])
# left, bottom, width, height]
cax = axes([0.0, 0.0, 1.0, 0.1])
colorbar(cax=cax,orientation='horizontal')
show()
