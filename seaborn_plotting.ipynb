# %%
# %matplotlib inline 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
ax = sns.heatmap(flights, annot=True, fmt="d", linewidths=.5)
# plt.annotate('1949','December',)
# ax.annotate(xycoords='figure points')

# %%
for text in ax.texts:
    text.set_size(12)
    print(text)
    if text.get_text() == '118':
        text.set_size(12)
        text.set_color('blue')
        text.set_weight('bold')
        text.set_style('italic')
# Out:
# Text(0.5,0.5,u'118')
# Text(1.5,0.5,u'140')
# Text(2.5,0.5,u'166')
# Text(3.5,0.5,u'194')
# Text(4.5,0.5,u'201')
# Text(5.5,0.5,u'229')
# Text(6.5,0.5,u'278')
# Text(7.5,0.5,u'306')
# Text(8.5,0.5,u'336')
# Text(9.5,0.5,u'337')
# Text(10.5,0.5,u'405')
# Text(11.5,0.5,u'432')
# Text(0.5,1.5,u'104')
# Text(1.5,1.5,u'114')
# Text(2.5,1.5,u'146')
# Text(3.5,1.5,u'172')
# Text(4.5,1.5,u'180')
# Text(5.5,1.5,u'203')
# Text(6.5,1.5,u'237')
# Text(7.5,1.5,u'271')
# Text(8.5,1.5,u'305')
# Text(9.5,1.5,u'310')
# Text(10.5,1.5,u'362')
# Text(11.5,1.5,u'390')
# Text(0.5,2.5,u'119')
# Text(1.5,2.5,u'133')
# Text(2.5,2.5,u'162')
# Text(3.5,2.5,u'191')
# Text(4.5,2.5,u'211')
# Text(5.5,2.5,u'229')
# Text(6.5,2.5,u'274')
# Text(7.5,2.5,u'306')
# Text(8.5,2.5,u'347')
# Text(9.5,2.5,u'359')
# Text(10.5,2.5,u'407')
# Text(11.5,2.5,u'461')
# Text(0.5,3.5,u'136')
# Text(1.5,3.5,u'158')
# Text(2.5,3.5,u'184')
# Text(3.5,3.5,u'209')
# Text(4.5,3.5,u'237')
# Text(5.5,3.5,u'259')
# Text(6.5,3.5,u'312')
# Text(7.5,3.5,u'355')
# Text(8.5,3.5,u'404')
# Text(9.5,3.5,u'404')
# Text(10.5,3.5,u'463')
# Text(11.5,3.5,u'508')
# Text(0.5,4.5,u'148')
# Text(1.5,4.5,u'170')
# Text(2.5,4.5,u'199')
# Text(3.5,4.5,u'242')
# Text(4.5,4.5,u'272')
# Text(5.5,4.5,u'293')
# Text(6.5,4.5,u'347')
# Text(7.5,4.5,u'405')
# Text(8.5,4.5,u'467')
# Text(9.5,4.5,u'505')
# Text(10.5,4.5,u'559')
# Text(11.5,4.5,u'606')
# Text(0.5,5.5,u'148')
# Text(1.5,5.5,u'170')
# Text(2.5,5.5,u'199')
# Text(3.5,5.5,u'230')
# Text(4.5,5.5,u'264')
# Text(5.5,5.5,u'302')
# Text(6.5,5.5,u'364')
# Text(7.5,5.5,u'413')
# Text(8.5,5.5,u'465')
# Text(9.5,5.5,u'491')
# Text(10.5,5.5,u'548')
# Text(11.5,5.5,u'622')
# Text(0.5,6.5,u'135')
# Text(1.5,6.5,u'149')
# Text(2.5,6.5,u'178')
# Text(3.5,6.5,u'218')
# Text(4.5,6.5,u'243')
# Text(5.5,6.5,u'264')
# Text(6.5,6.5,u'315')
# Text(7.5,6.5,u'374')
# Text(8.5,6.5,u'422')
# Text(9.5,6.5,u'435')
# Text(10.5,6.5,u'472')
# Text(11.5,6.5,u'535')
# Text(0.5,7.5,u'121')
# Text(1.5,7.5,u'125')
# Text(2.5,7.5,u'172')
# Text(3.5,7.5,u'183')
# Text(4.5,7.5,u'229')
# Text(5.5,7.5,u'234')
# Text(6.5,7.5,u'270')
# Text(7.5,7.5,u'318')
# Text(8.5,7.5,u'355')
# Text(9.5,7.5,u'363')
# Text(10.5,7.5,u'420')
# Text(11.5,7.5,u'472')
# Text(0.5,8.5,u'129')
# Text(1.5,8.5,u'135')
# Text(2.5,8.5,u'163')
# Text(3.5,8.5,u'181')
# Text(4.5,8.5,u'235')
# Text(5.5,8.5,u'227')
# Text(6.5,8.5,u'269')
# Text(7.5,8.5,u'313')
# Text(8.5,8.5,u'348')
# Text(9.5,8.5,u'348')
# Text(10.5,8.5,u'396')
# Text(11.5,8.5,u'461')
# Text(0.5,9.5,u'132')
# Text(1.5,9.5,u'141')
# Text(2.5,9.5,u'178')
# Text(3.5,9.5,u'193')
# Text(4.5,9.5,u'236')
# Text(5.5,9.5,u'235')
# Text(6.5,9.5,u'267')
# Text(7.5,9.5,u'317')
# Text(8.5,9.5,u'356')
# Text(9.5,9.5,u'362')
# Text(10.5,9.5,u'406')
# Text(11.5,9.5,u'419')
# Text(0.5,10.5,u'118')
# Text(1.5,10.5,u'126')
# Text(2.5,10.5,u'150')
# Text(3.5,10.5,u'180')
# Text(4.5,10.5,u'196')
# Text(5.5,10.5,u'188')
# Text(6.5,10.5,u'233')
# Text(7.5,10.5,u'277')
# Text(8.5,10.5,u'301')
# Text(9.5,10.5,u'318')
# Text(10.5,10.5,u'342')
# Text(11.5,10.5,u'391')
# Text(0.5,11.5,u'112')
# Text(1.5,11.5,u'115')
# Text(2.5,11.5,u'145')
# Text(3.5,11.5,u'171')
# Text(4.5,11.5,u'196')
# Text(5.5,11.5,u'204')
# Text(6.5,11.5,u'242')
# Text(7.5,11.5,u'284')
# Text(8.5,11.5,u'315')
# Text(9.5,11.5,u'340')
# Text(10.5,11.5,u'360')
# Text(11.5,11.5,u'417')

# %%
ax.get_axes()
